# %% [markdown]
# # Exploring the data

# %% [markdown]
# ### Working with tabular data

# %%
import arcpy
import os
import pandas as pd

# Read the data and store it in a pandas dataframe, df.  
# A data frame is a 2-dimensional data structure.  
projectDir = r"C:\Users\echoi4\Desktop\New\esterArcGISProject-20230428T013544Z-001\esterArcGISProject" ## Replace with your data directory
try:
    # When working inside ArcGIS Pro,
    # use the project name "CURRENT"
    aprx = arcpy.mp.ArcGISProject("CURRENT")
except:
    # When working outside of ArcGIS Pro,
    # use the project full path file name.
    aprx = arcpy.mp.ArcGISProject(project_dir + "/estherArcGISProject.aprx")
    
workingDir = projectDir + "\outputFreq\\"
fileGDB = projectDir + '\esterArcGISProject.gdb\\'
visDir = workingDir + '\picsFreq\\'

# Create output directories if they don't already exist.
dirs = [workingDir, visDir]
for d in dirs:
    if not os.path.exists(d):
        os.mkdir(d)

myData = projectDir + '\Moth.csv' #'tuta_absoluta.csv' 
df = pd.read_csv(myData)

# Print the first 5 records to get a feel for the data.
df.head()
# Out:
#    Unnamed: 0  ...                                          Full Text
# 0           2  ...  ...sharks caught was a mixture of 57 black tip...
# 1           3  ...  @K24Tv @LindaKoskey Tuta Absoluta remains the ...
# 2           4  ...  ...species. July ‘Tuta absoluta’ tomato pest d...
# 3           5  ...  ...sullo sviluppo di peronospora e Tuta absolu...
# 4           6  ...  ...spotted stem borer, Maize Lethal Necrosis D...
#
# [5 rows x 6 columns]

# %%
import os
import arcpy
import pandas as pd

# Read the data and store it in a pandas dataframe, df.  
# A data frame is a 2-dimensional data structure.  
projectDir = r"C:\Users\echoi4\Desktop\New\esterArcGISProject-20230428T013544Z-001\esterArcGISProject" ## Replace with your data directory
aprx = arcpy.mp.ArcGISProject(projectDir + '\estherArcGISProject.aprx') ## When working in ArcGIS Pro, Change this to aprx = arcpy.mp.ArcGISProject("CURRENT")
workingDir = projectDir + "\outputFreq\\"
fileGDB = projectDir + '\esterArcGISProject.gdb\\'
visDir = workingDir + '\picsFreq\\'

# Create output directories if they don't already exist.
dirs = [workingDir, visDir]
for d in dirs:
    if not os.path.exists(d):
        os.mkdir(d)

myData = projectDir + '\Moth.csv' #'tuta_absoluta.csv' 
df = pd.read_csv(myData)

# Print the first 5 records to get a feel for the data.
df.head()
# Out:
#    Unnamed: 0  ...                                          Full Text
# 0           2  ...  ...sharks caught was a mixture of 57 black tip...
# 1           3  ...  @K24Tv @LindaKoskey Tuta Absoluta remains the ...
# 2           4  ...  ...species. July ‘Tuta absoluta’ tomato pest d...
# 3           5  ...  ...sullo sviluppo di peronospora e Tuta absolu...
# 4           6  ...  ...spotted stem borer, Maize Lethal Necrosis D...
#
# [5 rows x 6 columns]

# %%
df['Year']= df['Month']

# %%
df
# Out:
#       Unnamed: 0  ...                                          Full Text
# 0              2  ...  ...sharks caught was a mixture of 57 black tip...
# 1              3  ...  @K24Tv @LindaKoskey Tuta Absoluta remains the ...
# 2              4  ...  ...species. July ‘Tuta absoluta’ tomato pest d...
# 3              5  ...  ...sullo sviluppo di peronospora e Tuta absolu...
# 4              6  ...  ...spotted stem borer, Maize Lethal Necrosis D...
# ...          ...  ...                                                ...
# 3459        4131  ...  RT @Forteoas @cmashx @corporatefarmg1 @muchare...
# 3460        4133  ...  @cmashx @corporatefarmg1 @mucharedzeyi @Fran_M...
# 3461        4134  ...  RT @corporatefarmg1 Tuta absoluta Lets not onl...
# 3462        4135  ...  По данным пресс-службы Россельхознадзора, соот...
# 3463        4136  ...  RT @corporatefarmg1 Tuta absoluta Lets not onl...
#
# [3464 rows x 6 columns]

# %%
# What fields does the data have?
df.columns
# Out:
# Index(['Unnamed: 0', 'Page Type', 'Country', 'Year', 'Month', 'Full Text'], dtype='object')

# %%
# How many columns and rows does the data have?
df.shape
# Out:
# (3464, 6)

# %%
# Which countries are there in the "Country" field?
# The Series method named unique returns a Numpy array containing the unique values in a series. 
df['Country'].unique()
# Out:
# array(['Seychelles', 'Kenya', 'Italy', 'Australia', 'Singapore', 'Spain',
#        'Russia', 'Brazil', 'Netherlands', 'United Kingdom', 'Chile',
#        'Germany', 'Zimbabwe', 'China', 'Nigeria', 'Cambodia', 'Romania',
#        'Azerbaijan', 'United States', 'Turkey', 'Argentina',
#        'Switzerland', 'Ghana', 'South Africa', 'Uganda', 'Indonesia',
#        'Democratic Republic of the Congo', 'Botswana', 'Belgium',
#        'Saudi Arabia', 'Ukraine', 'Thailand', 'France', 'Greece',
#        'Hungary', 'Bosnia and Herzegovina', 'Republic of Serbia', 'Japan',
#        'United Republic of Tanzania', 'Poland', 'Morocco', 'Mexico',
#        'Iran', 'Lebanon', 'United Arab Emirates', 'Peru', 'Zambia',
#        'Venezuela', 'Tunisia', 'India', 'New Zealand', 'Taiwan',
#        'Somalia', 'Norway', 'Dominican Republic', 'Kazakhstan',
#        'Ethiopia', 'Paraguay', 'Colombia', 'Cape Verde', 'Angola',
#        'Portugal', 'Ivory Coast', 'Aruba', 'Oman', 'Slovakia', 'Namibia',
#        'Canada', 'Jordan', 'North Macedonia',
#        'British Indian Ocean Territory', 'South Korea', 'Cayman Islands',
#        'Cameroon', 'Kyrgyzstan', 'Jamaica', 'Bangladesh', 'Algeria',
#        'Mozambique', 'Malta', 'Armenia', 'Burkina Faso', 'Eritrea',
#        'Monaco', 'Vietnam', 'Sweden', 'Senegal', 'Turkmenistan',
#        'Czech Republic', 'Panama', 'Republic of Ireland', 'Brunei',
#        'Malawi', 'Malaysia', 'Philippines', 'Pakistan', 'Mongolia',
#        'Luxembourg', 'Finland', 'Mauritius', 'Tajikistan', 'Austria',
#        'Egypt', 'Bulgaria', 'Rwanda', 'Croatia', 'British Virgin Islands',
#        'Ecuador'], dtype=object)

# %%
# Change the name in the Country column for USA to match GIS data name for USA
df['Country'] = df['Country'].replace('United States of America','United States')
df['Country'].unique()
# Out:
# array(['Seychelles', 'Kenya', 'Italy', 'Australia', 'Singapore', 'Spain',
#        'Russia', 'Brazil', 'Netherlands', 'United Kingdom', 'Chile',
#        'Germany', 'Zimbabwe', 'China', 'Nigeria', 'Cambodia', 'Romania',
#        'Azerbaijan', 'United States', 'Turkey', 'Argentina',
#        'Switzerland', 'Ghana', 'South Africa', 'Uganda', 'Indonesia',
#        'Democratic Republic of the Congo', 'Botswana', 'Belgium',
#        'Saudi Arabia', 'Ukraine', 'Thailand', 'France', 'Greece',
#        'Hungary', 'Bosnia and Herzegovina', 'Republic of Serbia', 'Japan',
#        'United Republic of Tanzania', 'Poland', 'Morocco', 'Mexico',
#        'Iran', 'Lebanon', 'United Arab Emirates', 'Peru', 'Zambia',
#        'Venezuela', 'Tunisia', 'India', 'New Zealand', 'Taiwan',
#        'Somalia', 'Norway', 'Dominican Republic', 'Kazakhstan',
#        'Ethiopia', 'Paraguay', 'Colombia', 'Cape Verde', 'Angola',
#        'Portugal', 'Ivory Coast', 'Aruba', 'Oman', 'Slovakia', 'Namibia',
#        'Canada', 'Jordan', 'North Macedonia',
#        'British Indian Ocean Territory', 'South Korea', 'Cayman Islands',
#        'Cameroon', 'Kyrgyzstan', 'Jamaica', 'Bangladesh', 'Algeria',
#        'Mozambique', 'Malta', 'Armenia', 'Burkina Faso', 'Eritrea',
#        'Monaco', 'Vietnam', 'Sweden', 'Senegal', 'Turkmenistan',
#        'Czech Republic', 'Panama', 'Republic of Ireland', 'Brunei',
#        'Malawi', 'Malaysia', 'Philippines', 'Pakistan', 'Mongolia',
#        'Luxembourg', 'Finland', 'Mauritius', 'Tajikistan', 'Austria',
#        'Egypt', 'Bulgaria', 'Rwanda', 'Croatia', 'British Virgin Islands',
#        'Ecuador'], dtype=object)

# %%
# How many countries is that?
# Use the built-in len method to find the length of the array of unique country names.
print(len(df['Country'].unique()))
# Out:
# 108

# %% [markdown]
# ### Aggregating the posts to get a weight for each country
# We would like to visualize how many posts are appearing in each country each year.  This means we need to get a frequency count by country for each year.
# We'll use Pandas (although this can also be done with arcpy by calling TabletoTable to make a DBF table and then calling the Frequency tool.)

# %% [markdown]
# ##### Get a frequency table with Pandas
#
# The dataframe method named value_counts can be used to get the frequency of the posts in a country each year.  This returns a pandas series.

# %%
freq_series = df.value_counts(["Year", "Country"])
freq_df = freq_series.to_frame()
freq_df
# Out:
#                       0
# Year Country
# 9    United States  123
# 7    Turkey         109
#      Spain           83
# 6    Russia          74
# 2    United States   64
# ...                 ...
# 9    Ukraine          1
# 6    Monaco           1
#      Jordan           1
# 2    Ghana            1
# 1    Argentina        1
#
# [498 rows x 1 columns]

# %% [markdown]
# See the dimensions in the above output?  This makes each year + country pairings the index for each row (the unique identifier field).   And the frequncy value is the **one column** .  The following code lists the index values (year-country tuples):

# %%
print(freq_df.index.values)
print(freq_df.columns)
# Out:
# [(9, 'United States') (7, 'Turkey') (7, 'Spain') (6, 'Russia')
#  (2, 'United States') (10, 'South Africa') (8, 'Spain') (9, 'Turkey')
#  (6, 'Spain') (5, 'Spain') (10, 'Spain') (12, 'Russia') (2, 'Azerbaijan')
#  (5, 'Russia') (2, 'Spain') (9, 'Netherlands') (11, 'Spain') (4, 'Kenya')
#  (12, 'Spain') (8, 'Russia') (4, 'Russia') (2, 'Russia') (11, 'Singapore')
#  (11, 'Thailand') (1, 'Russia') (7, 'Russia') (11, 'Netherlands')
#  (3, 'Russia') (3, 'United States') (5, 'Netherlands') (4, 'Spain')
#  (5, 'United States') (1, 'Spain') (6, 'Netherlands') (7, 'Brazil')
#  (11, 'Russia') (11, 'Italy') (7, 'Azerbaijan') (3, 'Spain') (4, 'Italy')
#  (1, 'Netherlands') (9, 'Spain') (7, 'United States')
#  (11, 'United States') (5, 'Italy') (5, 'Kenya') (3, 'Kenya')
#  (6, 'France') (7, 'Chile') (12, 'Brazil') (4, 'Azerbaijan') (9, 'Italy')
#  (5, 'United Kingdom') (1, 'Belgium') (6, 'United States')
#  (5, 'South Africa') (1, 'Azerbaijan') (6, 'Kenya') (9, 'Greece')
#  (8, 'Italy') (10, 'Netherlands') (5, 'Azerbaijan') (2, 'Kenya')
#  (8, 'Netherlands') (9, 'Kenya') (2, 'Bulgaria') (10, 'Russia')
#  (9, 'Brazil') (8, 'United States') (12, 'Kenya') (6, 'Azerbaijan')
#  (10, 'Greece') (3, 'Netherlands') (6, 'Italy') (8, 'France')
#  (9, 'Russia') (5, 'France') (3, 'Azerbaijan') (7, 'Netherlands')
#  (2, 'Portugal') (5, 'India') (7, 'Italy') (2, 'Zimbabwe')
#  (4, 'United States') (12, 'Nigeria') (12, 'Italy') (12, 'Azerbaijan')
#  (2, 'Netherlands') (1, 'Kenya') (2, 'Italy') (11, 'Kenya')
#  (9, 'Zimbabwe') (12, 'United States') (11, 'Nigeria') (2, 'Armenia')
#  (3, 'Argentina') (8, 'Kenya') (9, 'Canada') (7, 'Kenya')
#  (7, 'United Republic of Tanzania') (6, 'Greece') (7, 'France')
#  (8, 'Turkey') (12, 'Turkey') (10, 'United States') (3, 'Chile')
#  (12, 'Singapore') (6, 'South Africa') (9, 'Romania') (7, 'Germany')
#  (9, 'United Kingdom') (5, 'Vietnam') (10, 'Portugal') (7, 'Ukraine')
#  (11, 'United Kingdom') (3, 'Italy') (11, 'India') (11, 'Australia')
#  (10, 'Zimbabwe') (10, 'Italy') (2, 'Canada') (7, 'Romania') (6, 'Turkey')
#  (5, 'Turkey') (6, 'Australia') (8, 'Brazil') (8, 'South Africa')
#  (9, 'South Africa') (10, 'Ukraine') (10, 'United Kingdom') (11, 'Brazil')
#  (12, 'Argentina') (12, 'South Africa') (12, 'Thailand') (12, 'Uganda')
#  (4, 'South Africa') (12, 'Zimbabwe') (2, 'Romania') (1, 'Bulgaria')
#  (3, 'Ukraine') (1, 'China') (3, 'Thailand') (2, 'South Africa')
#  (3, 'France') (1, 'Venezuela') (4, 'Nigeria') (5, 'Portugal')
#  (1, 'Italy') (3, 'Armenia') (9, 'France') (8, 'Seychelles') (2, 'Uganda')
#  (5, 'Germany') (5, 'Ghana') (3, 'Romania') (7, 'Cape Verde')
#  (6, 'United Kingdom') (1, 'Romania') (10, 'Kenya') (4, 'France')
#  (6, 'Zimbabwe') (11, 'South Africa') (3, 'Nigeria') (9, 'Australia')
#  (4, 'Turkey') (10, 'Argentina') (7, 'Armenia') (11, 'Greece')
#  (2, 'France') (8, 'India') (1, 'United States') (7, 'South Africa')
#  (1, 'Zimbabwe') (2, 'India') (6, 'Chile') (2, 'Germany') (2, 'Brazil')
#  (5, 'Romania') (2, 'Argentina') (4, 'Egypt') (2, 'Nigeria') (9, 'India')
#  (3, 'Turkey') (11, 'Turkey') (6, 'Colombia') (5, 'Canada')
#  (7, 'United Kingdom') (4, 'Mexico') (5, 'Argentina') (5, 'Australia')
#  (4, 'Portugal') (4, 'Ukraine') (3, 'Australia') (8, 'Chile')
#  (4, 'Romania') (12, 'Belgium') (8, 'United Republic of Tanzania')
#  (8, 'Azerbaijan') (1, 'Brazil') (11, 'Switzerland') (12, 'Saudi Arabia')
#  (6, 'India') (10, 'Australia') (3, 'Bulgaria') (3, 'Venezuela')
#  (6, 'Nigeria') (8, 'Zimbabwe') (8, 'Germany') (8, 'Greece')
#  (6, 'Republic of Serbia') (7, 'Belgium') (7, 'Seychelles') (3, 'Brazil')
#  (8, 'Namibia') (3, 'Malawi') (9, 'Germany') (1, 'Armenia')
#  (3, 'South Africa') (2, 'Turkey') (6, 'Romania') (10, 'Romania')
#  (10, 'Nigeria') (11, 'Belgium') (1, 'United Kingdom') (1, 'Ukraine')
#  (5, 'Philippines') (11, 'Morocco') (5, 'Mexico') (10, 'Paraguay')
#  (5, 'Malaysia') (1, 'Nigeria') (5, 'China') (5, 'Cambodia')
#  (12, 'Germany') (12, 'Greece') (4, 'Zimbabwe') (12, 'Netherlands')
#  (1, 'France') (12, 'Ukraine') (12, 'United Kingdom') (11, 'France')
#  (8, 'Australia') (5, 'Ukraine') (11, 'Argentina') (5, 'Zimbabwe')
#  (2, 'Australia') (10, 'United Republic of Tanzania') (8, 'Cape Verde')
#  (10, 'Brazil') (8, 'Romania') (8, 'Portugal') (10, 'Venezuela')
#  (12, 'Chile') (8, 'North Macedonia') (12, 'China')
#  (12, 'Democratic Republic of the Congo') (12, 'France') (8, 'Malta')
#  (8, 'Jamaica') (9, 'Venezuela') (8, 'Armenia') (1, 'Jordan') (1, 'India')
#  (1, 'Greece') (3, 'Canada') (10, 'Uganda') (12, 'Seychelles')
#  (1, 'Chile') (9, 'United Republic of Tanzania') (8, 'Switzerland')
#  (9, 'Namibia') (11, 'Peru') (9, 'Kyrgyzstan') (11, 'Germany')
#  (11, 'Azerbaijan') (9, 'Seychelles') (11, 'Japan') (1, 'Tajikistan')
#  (2, 'Namibia') (9, 'Colombia') (1, 'South Africa') (9, 'China')
#  (11, 'Poland') (12, 'Australia') (10, 'Zambia') (9, 'Switzerland')
#  (1, 'Portugal') (9, 'Uganda') (11, 'Ukraine') (2, 'Ivory Coast')
#  (11, 'United Republic of Tanzania') (1, 'Morocco') (11, 'Zimbabwe')
#  (8, 'Ukraine') (9, 'Angola') (8, 'Mozambique') (8, 'Argentina')
#  (5, 'Malawi') (7, 'Colombia') (7, 'China') (3, 'Switzerland')
#  (7, 'Australia') (7, 'Argentina') (5, 'Ethiopia')
#  (6, 'United Republic of Tanzania') (5, 'Greece') (6, 'Switzerland')
#  (6, 'Sweden') (6, 'Slovakia') (6, 'Senegal') (5, 'Kazakhstan')
#  (6, 'Portugal') (5, 'Armenia') (6, 'Panama') (5, 'Namibia') (6, 'Mexico')
#  (3, 'United Kingdom') (5, 'Nigeria') (5, 'Republic of Serbia')
#  (5, 'Singapore') (4, 'China') (6, 'Germany') (4, 'Argentina')
#  (5, 'Thailand') (6, 'Brazil') (5, 'United Republic of Tanzania')
#  (4, 'Jordan') (4, 'Hungary') (6, 'Argentina') (7, 'Greece')
#  (4, 'Tajikistan') (3, 'Germany') (3, 'Jordan') (4, 'Netherlands')
#  (7, 'Mexico') (3, 'China') (7, 'Ethiopia') (4, 'Republic of Serbia')
#  (11, 'New Zealand') (5, 'Pakistan') (6, 'Algeria') (11, 'Lebanon')
#  (11, 'Mexico') (5, 'New Zealand') (4, 'Ethiopia') (4, 'Mozambique')
#  (4, 'Republic of Ireland') (1, 'Czech Republic')
#  (1, 'Dominican Republic') (11, 'Norway') (5, 'Mozambique')
#  (5, 'Mongolia') (12, 'Switzerland') (11, 'Iran') (4, 'Slovakia')
#  (11, 'Hungary') (4, 'Rwanda') (1, 'Republic of Serbia')
#  (1, 'British Virgin Islands') (4, 'Chile') (5, 'Switzerland')
#  (4, 'Belgium') (11, 'Dominican Republic') (11, 'China') (5, 'Venezuela')
#  (4, 'Botswana') (4, 'Cameroon') (5, 'United Arab Emirates')
#  (4, 'Bulgaria') (11, 'Romania') (12, 'Ghana') (11, 'Seychelles')
#  (11, 'Venezuela') (11, 'Zambia') (4, 'Malaysia') (4, 'Venezuela')
#  (1, 'Kyrgyzstan') (4, 'Japan') (5, 'Finland')
#  (12, 'Bosnia and Herzegovina') (12, 'Botswana') (5, 'Chile')
#  (12, 'Indonesia') (12, 'Hungary') (12, 'Cambodia') (5, 'Brunei')
#  (5, 'Brazil') (5, 'Algeria') (4, 'United Republic of Tanzania')
#  (5, 'Hungary') (5, 'Mauritius') (4, 'Austria') (5, 'Bangladesh')
#  (4, 'Switzerland') (1, 'Ecuador') (1, 'Panama') (5, 'Luxembourg')
#  (11, 'Taiwan') (1, 'North Macedonia') (11, 'Tunisia') (12, 'Romania')
#  (11, 'Uganda') (12, 'Republic of Serbia') (5, 'Japan')
#  (11, 'United Arab Emirates') (4, 'United Arab Emirates') (4, 'Germany')
#  (11, 'Somalia') (2, 'Ethiopia') (2, 'Austria') (9, 'Mexico')
#  (2, 'United Republic of Tanzania') (2, 'United Kingdom') (7, 'Eritrea')
#  (8, 'Taiwan') (8, 'United Kingdom') (7, 'Burkina Faso')
#  (7, 'Bosnia and Herzegovina') (2, 'Tajikistan')
#  (9, 'British Indian Ocean Territory') (9, 'Cameroon') (2, 'Switzerland')
#  (9, 'Cape Verde') (9, 'Cayman Islands') (6, 'Vietnam')
#  (6, 'Turkmenistan') (9, 'Ghana') (3, 'Uganda') (2, 'Senegal')
#  (9, 'Jordan') (3, 'Republic of Ireland') (3, 'Poland')
#  (8, 'Republic of Serbia') (8, 'Hungary') (8, 'Bangladesh')
#  (7, 'Zimbabwe') (8, 'Canada') (7, 'Venezuela') (8, 'China')
#  (8, 'Ethiopia') (3, 'Czech Republic') (3, 'Greece') (3, 'Hungary')
#  (7, 'Nigeria') (3, 'India') (7, 'Republic of Serbia') (8, 'Japan')
#  (3, 'Belgium') (7, 'Portugal') (8, 'Mexico') (8, 'Morocco')
#  (7, 'North Macedonia') (2, 'Rwanda') (9, 'Morocco') (4, 'Australia')
#  (6, 'Republic of Ireland') (4, 'Algeria') (10, 'Cape Verde')
#  (10, 'Chile') (10, 'China') (10, 'Colombia') (10, 'Ethiopia')
#  (10, 'Ivory Coast') (10, 'Kazakhstan') (6, 'Ethiopia') (10, 'Mexico')
#  (8, 'Algeria') (6, 'Czech Republic') (6, 'China') (2, 'Croatia')
#  (2, 'Colombia') (10, 'Seychelles') (2, 'China') (6, 'Botswana')
#  (10, 'Turkey') (6, 'Indonesia') (10, 'Aruba') (6, 'Iran')
#  (2, 'New Zealand') (9, 'New Zealand') (9, 'Nigeria')
#  (9, 'North Macedonia') (9, 'Oman') (9, 'Poland') (9, 'Portugal')
#  (2, 'Poland') (9, 'Slovakia') (9, 'South Korea') (10, 'Angola')
#  (6, 'North Macedonia') (3, 'United Arab Emirates') (2, 'Mozambique')
#  (6, 'Mozambique') (9, 'Ukraine') (6, 'Monaco') (6, 'Jordan') (2, 'Ghana')
#  (1, 'Argentina')]
# RangeIndex(start=0, stop=1, step=1)

# %% [markdown]
# Following this approach described on [stackoverflow]{https://stackoverflow.com/questions/47136436/python-pandas-convert-value-counts-output-to-dataframe}, we'll reset the index.  This generates a new unique ID (index) for each row.   Then we can rename the columns, to name our new column "Frequency".

# %%
freq_df_reset = freq_df.reset_index()
freq_df_reset
# Rename the last column to "Frequency"
freq_df_reset.columns = ["Year", "Country","Frequency"]
## Add code to print the head of freq_df_reset

# %%
# Get the overall maximum and minimum frequencies for later use.
max_country_count = freq_df_reset['Frequency'].max()
min_country_count = freq_df_reset['Frequency'].min()
print(max_country_count)
print(min_country_count)

## Add code to print the maximum and minimum year in the data.
# Out:
# 123
# 1

# %% [markdown]
# ### Make a copy of the worldwide countries dataset
#
# Other data will be joined to this, so we want to preserve the original before modifying the table.
#
# Data source:
# [ArcGIS Hub World Countries Generalized] (https://hub.arcgis.com/datasets/2b93b06dc0dc4e809d3c8db5cb96ba69_0/explore?location=-0.101905%2C0.000000%2C2.09)

# %%
import arcpy
arcpy.env.workspace = projectDir + r'esterArcGISProject.gdb'
arcpy.env.overwriteOutput = True
worldData = 'world_countries'
worldDataCopy = workingDir + 'worldEstherFreq.shp'
arcpy.CopyFeatures_management(worldData, worldDataCopy)
# Out:
# <Result 'C:\\Users\\echoi4\\Desktop\\New\\esterArcGISProject-20230428T013544Z-001\\esterArcGISProject\\outputFreq\\worldEstherFreq.shp'>

# %%
# Get a the base name (without the extention) of the input data.  We'll use this to name files in the next part.
baseName = os.path.basename(myData)
baseName = os.path.splitext(baseName)[0]
baseName = baseName.split("_")[0]
baseName
# Out:
# 'Moth'

# %% [markdown]
# ### Create a table for each time step and join the tables with the GIS data

# %%
import traceback
# Create an empty dictionary to store the number of records per year.
yearly_count = {}
max_country_count = freq_df_reset['Frequency'].max()
min_country_count = freq_df_reset['Frequency'].min()
# For each year in the reduced dataset, create a csv file.

for yr in sorted(freq_df_reset['Year'].unique()):
    # Select rows based on the year
    rslt_df = freq_df_reset[freq_df_reset['Year'] == yr]
    recordsThisYear = rslt_df['Frequency'].sum() 
    print(f"Number of records in {yr}: {recordsThisYear}" ) 
    yearly_count[yr] = len(rslt_df)

    # Prepare an output name
    annualCSV = workingDir + f'{baseName}{yr}.csv'
    
    # Write the data frame to csv
    rslt_df.to_csv(annualCSV)
    
    print(f'Year:   {yr}')
    print(rslt_df['Country'].unique())
    
    # Join the data
    joinedData = arcpy.management.AddJoin(
        in_layer_or_view = worldDataCopy, 
        in_field = 'COUNTRY', 
        join_table = annualCSV, 
        join_field = 'Country', 
    join_type = 'KEEP_COMMON')
    
    curData = fileGDB + f'{baseName}{yr}'
    try:
        # The frequency field automatic name is quite long.  E.g., esther_reduced2013_csv_Frequency
        # Let's rename it.
        
        cur_frequency_field = f'{os.path.basename(annualCSV).replace(".","_")}_Frequency'
        frequency_field = 'Count'
        arcpy.CopyFeatures_management(joinedData, curData)
        fds = arcpy.ListFields(curData)
        print(f"Field names before: {[f.name for f in fds]}")
        arcpy.management.AlterField(curData, cur_frequency_field, frequency_field, frequency_field)
        fds = arcpy.ListFields(curData)
        print(f"Field names after: {[f.name for f in fds]}")
        shpData = workingDir + f'{baseName}{yr}.shp'
        arcpy.management.CopyFeatures(curData, shpData)
        
    except:
        traceback.print_exc()
        print("File already exists.  New copy not created.")
# Out:
# Number of records in 1: 197
# Year:   1
# ['Russia' 'Spain' 'Netherlands' 'Belgium' 'Azerbaijan' 'Kenya' 'Bulgaria'
#  'China' 'Venezuela' 'Italy' 'Romania' 'United States' 'Zimbabwe' 'Brazil'
#  'Armenia' 'United Kingdom' 'Ukraine' 'Nigeria' 'France' 'Jordan' 'India'
#  'Greece' 'Chile' 'Tajikistan' 'South Africa' 'Portugal' 'Morocco'
#  'Czech Republic' 'Dominican Republic' 'Republic of Serbia'
#  'British Virgin Islands' 'Kyrgyzstan' 'Ecuador' 'Panama'
#  'North Macedonia' 'Argentina']
# Field names before: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth1_csv_Field1', 'Moth1_csv_Year', 'Moth1_csv_Country', 'Moth1_csv_Frequency', 'Shape_Length', 'Shape_Area']
# Field names after: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth1_csv_Field1', 'Moth1_csv_Year', 'Moth1_csv_Country', 'Count', 'Shape_Length', 'Shape_Area']
# Number of records in 2: 330
# Year:   2
# ['United States' 'Azerbaijan' 'Spain' 'Russia' 'Kenya' 'Bulgaria'
#  'Portugal' 'Zimbabwe' 'Netherlands' 'Italy' 'Armenia' 'Canada' 'Romania'
#  'South Africa' 'Uganda' 'France' 'India' 'Germany' 'Brazil' 'Argentina'
#  'Nigeria' 'Turkey' 'Australia' 'Namibia' 'Ivory Coast' 'Ethiopia'
#  'Austria' 'United Republic of Tanzania' 'United Kingdom' 'Tajikistan'
#  'Switzerland' 'Senegal' 'Rwanda' 'Croatia' 'Colombia' 'China'
#  'New Zealand' 'Poland' 'Mozambique' 'Ghana']
# Field names before: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth2_csv_Field1', 'Moth2_csv_Year', 'Moth2_csv_Country', 'Moth2_csv_Frequency', 'Shape_Length', 'Shape_Area']
# Field names after: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth2_csv_Field1', 'Moth2_csv_Year', 'Moth2_csv_Country', 'Count', 'Shape_Length', 'Shape_Area']
# Number of records in 3: 215
# Year:   3
# ['Russia' 'United States' 'Spain' 'Kenya' 'Netherlands' 'Azerbaijan'
#  'Argentina' 'Chile' 'Italy' 'Ukraine' 'Thailand' 'France' 'Armenia'
#  'Romania' 'Nigeria' 'Turkey' 'Australia' 'Bulgaria' 'Venezuela' 'Brazil'
#  'Malawi' 'South Africa' 'Canada' 'Switzerland' 'United Kingdom' 'Germany'
#  'Jordan' 'China' 'Uganda' 'Republic of Ireland' 'Poland' 'Czech Republic'
#  'Greece' 'Hungary' 'India' 'Belgium' 'United Arab Emirates']
# Field names before: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth3_csv_Field1', 'Moth3_csv_Year', 'Moth3_csv_Country', 'Moth3_csv_Frequency', 'Shape_Length', 'Shape_Area']
# Field names after: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth3_csv_Field1', 'Moth3_csv_Year', 'Moth3_csv_Country', 'Count', 'Shape_Length', 'Shape_Area']
# Number of records in 4: 220
# Year:   4
# ['Kenya' 'Russia' 'Spain' 'Italy' 'Azerbaijan' 'United States'
#  'South Africa' 'Nigeria' 'France' 'Turkey' 'Egypt' 'Mexico' 'Portugal'
#  'Ukraine' 'Romania' 'Zimbabwe' 'China' 'Argentina' 'Jordan' 'Hungary'
#  'Tajikistan' 'Netherlands' 'Republic of Serbia' 'Ethiopia' 'Mozambique'
#  'Republic of Ireland' 'Slovakia' 'Rwanda' 'Chile' 'Belgium' 'Botswana'
#  'Cameroon' 'Bulgaria' 'Malaysia' 'Venezuela' 'Japan'
#  'United Republic of Tanzania' 'Austria' 'Switzerland'
#  'United Arab Emirates' 'Germany' 'Australia' 'Algeria']
# Field names before: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth4_csv_Field1', 'Moth4_csv_Year', 'Moth4_csv_Country', 'Moth4_csv_Frequency', 'Shape_Length', 'Shape_Area']
# Field names after: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth4_csv_Field1', 'Moth4_csv_Year', 'Moth4_csv_Country', 'Count', 'Shape_Length', 'Shape_Area']
# Number of records in 5: 352
# Year:   5
# ['Spain' 'Russia' 'Netherlands' 'United States' 'Italy' 'Kenya'
#  'United Kingdom' 'South Africa' 'Azerbaijan' 'France' 'India' 'Vietnam'
#  'Turkey' 'Portugal' 'Germany' 'Ghana' 'Romania' 'Canada' 'Argentina'
#  'Australia' 'Philippines' 'Mexico' 'Malaysia' 'China' 'Cambodia'
#  'Ukraine' 'Zimbabwe' 'Malawi' 'Ethiopia' 'Greece' 'Kazakhstan' 'Armenia'
#  'Namibia' 'Nigeria' 'Republic of Serbia' 'Singapore' 'Thailand'
#  'United Republic of Tanzania' 'Pakistan' 'New Zealand' 'Mozambique'
#  'Mongolia' 'Switzerland' 'Venezuela' 'United Arab Emirates' 'Finland'
#  'Chile' 'Brunei' 'Brazil' 'Algeria' 'Hungary' 'Mauritius' 'Bangladesh'
#  'Luxembourg' 'Japan']
# Field names before: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth5_csv_Field1', 'Moth5_csv_Year', 'Moth5_csv_Country', 'Moth5_csv_Frequency', 'Shape_Length', 'Shape_Area']
# Field names after: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth5_csv_Field1', 'Moth5_csv_Year', 'Moth5_csv_Country', 'Count', 'Shape_Length', 'Shape_Area']
# Number of records in 6: 320
# Year:   6
# ['Russia' 'Spain' 'Netherlands' 'France' 'United States' 'Kenya'
#  'Azerbaijan' 'Italy' 'Greece' 'South Africa' 'Turkey' 'Australia'
#  'United Kingdom' 'Zimbabwe' 'Chile' 'Colombia' 'India' 'Nigeria'
#  'Republic of Serbia' 'Romania' 'United Republic of Tanzania'
#  'Switzerland' 'Sweden' 'Slovakia' 'Senegal' 'Portugal' 'Panama' 'Mexico'
#  'Germany' 'Brazil' 'Argentina' 'Algeria' 'Vietnam' 'Turkmenistan'
#  'Republic of Ireland' 'Ethiopia' 'Czech Republic' 'China' 'Botswana'
#  'Indonesia' 'Iran' 'North Macedonia' 'Mozambique' 'Monaco' 'Jordan']
# Field names before: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth6_csv_Field1', 'Moth6_csv_Year', 'Moth6_csv_Country', 'Moth6_csv_Frequency', 'Shape_Length', 'Shape_Area']
# Field names after: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth6_csv_Field1', 'Moth6_csv_Year', 'Moth6_csv_Country', 'Count', 'Shape_Length', 'Shape_Area']
# Number of records in 7: 415
# Year:   7
# ['Turkey' 'Spain' 'Russia' 'Brazil' 'Azerbaijan' 'United States' 'Chile'
#  'Netherlands' 'Italy' 'Kenya' 'United Republic of Tanzania' 'France'
#  'Germany' 'Ukraine' 'Romania' 'Cape Verde' 'Armenia' 'South Africa'
#  'United Kingdom' 'Belgium' 'Seychelles' 'Colombia' 'China' 'Australia'
#  'Argentina' 'Greece' 'Mexico' 'Ethiopia' 'Eritrea' 'Burkina Faso'
#  'Bosnia and Herzegovina' 'Zimbabwe' 'Venezuela' 'Nigeria'
#  'Republic of Serbia' 'Portugal' 'North Macedonia']
# Field names before: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth7_csv_Field1', 'Moth7_csv_Year', 'Moth7_csv_Country', 'Moth7_csv_Frequency', 'Shape_Length', 'Shape_Area']
# Field names after: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth7_csv_Field1', 'Moth7_csv_Year', 'Moth7_csv_Country', 'Count', 'Shape_Length', 'Shape_Area']
# Number of records in 8: 242
# Year:   8
# ['Spain' 'Russia' 'Italy' 'Netherlands' 'United States' 'France' 'Kenya'
#  'Turkey' 'Brazil' 'South Africa' 'Seychelles' 'India' 'Chile'
#  'United Republic of Tanzania' 'Azerbaijan' 'Zimbabwe' 'Germany' 'Greece'
#  'Namibia' 'Australia' 'Cape Verde' 'Romania' 'Portugal' 'North Macedonia'
#  'Malta' 'Jamaica' 'Armenia' 'Switzerland' 'Ukraine' 'Mozambique'
#  'Argentina' 'Taiwan' 'United Kingdom' 'Republic of Serbia' 'Hungary'
#  'Bangladesh' 'Canada' 'China' 'Ethiopia' 'Japan' 'Mexico' 'Morocco'
#  'Algeria']
# Field names before: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth8_csv_Field1', 'Moth8_csv_Year', 'Moth8_csv_Country', 'Moth8_csv_Frequency', 'Shape_Length', 'Shape_Area']
# Field names after: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth8_csv_Field1', 'Moth8_csv_Year', 'Moth8_csv_Country', 'Count', 'Shape_Length', 'Shape_Area']
# Number of records in 9: 402
# Year:   9
# ['United States' 'Turkey' 'Netherlands' 'Spain' 'Italy' 'Greece' 'Kenya'
#  'Brazil' 'Russia' 'Zimbabwe' 'Canada' 'Romania' 'United Kingdom'
#  'South Africa' 'France' 'Australia' 'India' 'Germany' 'Venezuela'
#  'United Republic of Tanzania' 'Namibia' 'Kyrgyzstan' 'Seychelles'
#  'Colombia' 'China' 'Switzerland' 'Uganda' 'Angola' 'Mexico'
#  'British Indian Ocean Territory' 'Cameroon' 'Cape Verde' 'Cayman Islands'
#  'Ghana' 'Jordan' 'Morocco' 'New Zealand' 'Nigeria' 'North Macedonia'
#  'Oman' 'Poland' 'Portugal' 'Slovakia' 'South Korea' 'Ukraine']
# Field names before: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth9_csv_Field1', 'Moth9_csv_Year', 'Moth9_csv_Country', 'Moth9_csv_Frequency', 'Shape_Length', 'Shape_Area']
# Field names after: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth9_csv_Field1', 'Moth9_csv_Year', 'Moth9_csv_Country', 'Count', 'Shape_Length', 'Shape_Area']
# Number of records in 10: 235
# Year:   10
# ['South Africa' 'Spain' 'Netherlands' 'Russia' 'Greece' 'United States'
#  'Portugal' 'Zimbabwe' 'Italy' 'Ukraine' 'United Kingdom' 'Kenya'
#  'Argentina' 'Australia' 'Romania' 'Nigeria' 'Paraguay'
#  'United Republic of Tanzania' 'Brazil' 'Venezuela' 'Uganda' 'Zambia'
#  'Cape Verde' 'Chile' 'China' 'Colombia' 'Ethiopia' 'Ivory Coast'
#  'Kazakhstan' 'Mexico' 'Seychelles' 'Turkey' 'Aruba' 'Angola']
# Field names before: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth10_csv_Field1', 'Moth10_csv_Year', 'Moth10_csv_Country', 'Moth10_csv_Frequency', 'Shape_Length', 'Shape_Area']
# Field names after: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth10_csv_Field1', 'Moth10_csv_Year', 'Moth10_csv_Country', 'Count', 'Shape_Length', 'Shape_Area']
# Number of records in 11: 299
# Year:   11
# ['Spain' 'Singapore' 'Thailand' 'Netherlands' 'Russia' 'Italy'
#  'United States' 'Kenya' 'Nigeria' 'United Kingdom' 'India' 'Australia'
#  'Brazil' 'South Africa' 'Greece' 'Turkey' 'Switzerland' 'Belgium'
#  'Morocco' 'France' 'Argentina' 'Peru' 'Germany' 'Azerbaijan' 'Japan'
#  'Poland' 'Ukraine' 'United Republic of Tanzania' 'Zimbabwe' 'New Zealand'
#  'Lebanon' 'Mexico' 'Norway' 'Iran' 'Hungary' 'Dominican Republic' 'China'
#  'Romania' 'Seychelles' 'Venezuela' 'Zambia' 'Taiwan' 'Tunisia' 'Uganda'
#  'United Arab Emirates' 'Somalia']
# Field names before: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth11_csv_Field1', 'Moth11_csv_Year', 'Moth11_csv_Country', 'Moth11_csv_Frequency', 'Shape_Length', 'Shape_Area']
# Field names after: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth11_csv_Field1', 'Moth11_csv_Year', 'Moth11_csv_Country', 'Count', 'Shape_Length', 'Shape_Area']
# Number of records in 12: 237
# Year:   12
# ['Russia' 'Spain' 'Brazil' 'Kenya' 'Nigeria' 'Italy' 'Azerbaijan'
#  'United States' 'Turkey' 'Singapore' 'Argentina' 'South Africa'
#  'Thailand' 'Uganda' 'Zimbabwe' 'Belgium' 'Saudi Arabia' 'Germany'
#  'Greece' 'Netherlands' 'Ukraine' 'United Kingdom' 'Chile' 'China'
#  'Democratic Republic of the Congo' 'France' 'Seychelles' 'Australia'
#  'Switzerland' 'Ghana' 'Bosnia and Herzegovina' 'Botswana' 'Indonesia'
#  'Hungary' 'Cambodia' 'Romania' 'Republic of Serbia']
# Field names before: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth12_csv_Field1', 'Moth12_csv_Year', 'Moth12_csv_Country', 'Moth12_csv_Frequency', 'Shape_Length', 'Shape_Area']
# Field names after: ['OBJECTID', 'Shape', 'worldEstherFreq_FID_1', 'worldEstherFreq_COUNTRY', 'worldEstherFreq_ISO', 'worldEstherFreq_COUNTRYAFF', 'worldEstherFreq_AFF_ISO', 'worldEstherFreq_SHAPE_Leng', 'worldEstherFreq_Shape_Le_1', 'Moth12_csv_Field1', 'Moth12_csv_Year', 'Moth12_csv_Country', 'Count', 'Shape_Length', 'Shape_Area']

# %% [markdown]
# #### Add records so that graduated colors will be normalized
#
# If we use graduated colors for the count on a year that has min 1 and max 5, the 5 will be colored the same as the max in another year that has max of 100.  As a way of normalizing the data for the purposes of visualizing it, we'll add a two new dummy records to each dataset. One new record will have the maximum value of all the years in the Count column.  The other will have the overall minimum in the Count column. The records will be dummies in the sense that they won't have any geometry, so they won't be displayed on the map, but they will still normalize the graduated colors so that the color steps are consistant across the years.

# %%
for yr in sorted(freq_df_reset['Year'].unique()):
    try:
        curData = fileGDB + f'{baseName}{yr}'
        with arcpy.da.InsertCursor(curData, [frequency_field]) as ic:
            newRecord = [max_country_count]
            ic.insertRow(newRecord)
            newRecord = [min_country_count]
            ic.insertRow(newRecord)
        del ic
    except:
        print(arcpy.GetMessages() )

# %% [markdown]
# ##### Color ramps
# We're going to use graduated color for our frequency counts.  You can specify color ramps by name.
# See a complete list of color ramps by uncommenting the following code (remove the hash tags at the beginning of each line)

# %%
#aprx = arcpy.mp.ArcGISProject(projectDir + 'estherArcGISProject.aprx')
#ramps = aprx.listColorRamps()
#for ramp in ramps:
#    print (ramp.name)

# %%
# aprx is the ArcGIS project object

# Get a list of maps in this project.
myMap = aprx.listMaps('Map')[0]
layers = myMap.listLayers()
layer_object = layers[0]
count = 0 
while "Worldwide" not in layer_object.name and count < len(layers):
    print(layer_object.name)
    myMap.removeLayer(layer_object)
    count = count + 1
    layer_object = layers[count]
    
for layer in layers:
    print(layer.name)
# Out:
# Worldwide Countries
# Human Geography Dark Label
# Human Geography Dark Detail
# Human Geography Dark Base

# %% [markdown]
# ### Create map layers and take screenshots
#
# We'll do this by looping through the years. Earlier, we created a shapefile for each year.  Now we'll make a layer for each shapefile.   We'll add it to the map, capture a screenshot (a png image), and turn then that layer's visibility off, so that we can do the same again with the next shapefile.

# %%
# Get a list of maps in this project.
myMap = aprx.listMaps('Map')[0]

custom_layout = aprx.listLayouts("*surround*")[0]
print(f"Layout elements on {custom_layout.name}:")
for elem in custom_layout.listElements():
    print("\t" + elem.name)
    if "Text" in elem.name:
        textbox = elem


RGBs = [[190, 210, 255, 60], [245, 122, 122, 60], [255, 255, 0, 60]]

# For each year in the data, add a layer and export an image of it.
for yr in sorted(freq_df_reset['Year'].unique()):

    # Get the name of the shapefile associated with the current year. 
    curData = workingDir + f'{baseName}{yr}.shp'
    
    # Add the shapefile as a layer on the map.
    myMap.addDataFromPath(curData)
    # Set the text string to current year
    textbox.text = yr
    
    # Now we need the layer object associated with our new layer. 
    # This gives access to the symbology properties of the layer.  
    # Get a list of layor objects for the layers on this map.
    layerObjects = myMap.listLayers()
    
    # Get the first one (the most recently added to the map)
    lay = layerObjects[0]

    print(f'Creating the {lay.name} layer.')
    
    sym = lay.symbology

    if lay.isFeatureLayer and hasattr(sym, "renderer"):
    
        # Modify the symbology object.
        sym.updateRenderer("GraduatedColorsRenderer")
        sym.renderer.classificationField = frequency_field
        sym.renderer.classificationMethod = "EqualInterval"
        ## Modify the number of breaks and the color ramp (see the code box before this for choices).
        sym.renderer.breakCount = 5
        sym.renderer.colorRamp = aprx.listColorRamps("Yellow-Orange-Red (5 Classes)")[0]

        # Set the layer's symbology to the updated symbology object.
        lay.symbology = sym 

    lay.symbology = sym
   
    # Capture a screen shot of the newly added and symbolized layer.
    outPic = visDir+f'{baseName}{str(yr).zfill(2)}.png'
    custom_layout.exportToPNG(outPic)
    # Turn the layer off to prepare for the adding the next one and capturing an image.
    lay.visible = False
    
    del lay

# Capture an image of the legend.
# Turn on one of the layers so that the legend will show the patches
lay = layerObjects[0]


lay.visible = True

# The project has a layout specifically designed to display only the legend.
# Here we're getting the layout object associated with it.  
# This layout view has the word 'legend' in it.
custom_layout = aprx.listLayouts("*legend*")[0]

# Enlarge the legend patches.  The default is too small for our purposes.
leg = custom_layout.listElements('LEGEND_ELEMENT')[0]

for itm in leg.items:
    # Specify the size in pts
    itm.patchHeight = 50
    itm.patchWidth = 100

legendName = visDir + f'legend.png'
custom_layout.exportToPNG(legendName)
    
del myMap
del aprx
# Out:
# Layout elements on Layout_w_surrounds:
# 	Legend
# 	Text
# 	North Arrow
# 	Map Frame
# Creating the Moth1 layer.
# Creating the Moth2 layer.
# Creating the Moth3 layer.
# Creating the Moth4 layer.
# Creating the Moth5 layer.
# Creating the Moth6 layer.
# Creating the Moth7 layer.
# Creating the Moth8 layer.
# Creating the Moth9 layer.
# Creating the Moth10 layer.
# Creating the Moth11 layer.
# Creating the Moth12 layer.

# %%
curData
x = "C:/gispy/esterArcGISProject/esterArcGISProject.gdb/Moth"
#myMap.addDataFromPath(x)
arcpy.Exists(x)
# Out:
# False

# %% [markdown]
# For more graduated color arcpy examples, see this 'how to' page: [https://support.esri.com/en/technical-article/000020468]
#
# For more information about legend items, see this ESRI help page: [https://pro.arcgis.com/en/pro-app/2.8/arcpy/mapping/legenditem-class.htm]

# %% [markdown]
# ### Creat an animation

# %%
import imageio
images = []
import os
mapPics = os.listdir(visDir)

movieName = visDir + '/movie.gif'
if os.path.exists(movieName):
    os.remove(movieName)

for pic in mapPics:
    if pic.endswith("png") and "legend" not in pic:
        images.append(imageio.imread(visDir + pic))


imageio.mimsave(movieName, images, duration=0.8)
image_count = len(images)
print('{} created using {} maps!'.format( movieName, image_count))
# Out:
# [113]:12: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
# C:\Users\echoi4\Desktop\New\esterArcGISProject-20230428T013544Z-001\esterArcGISProject\outputFreq\\picsFreq\/movie.gif created using 12 maps!

# %%
# Check file names.
print(mapPics)
# Out:
# ['legend.png', 'Moth01.png', 'Moth02.png', 'Moth03.png', 'Moth04.png', 'Moth05.png', 'Moth06.png', 'Moth07.png', 'Moth08.png', 'Moth09.png', 'Moth10.png', 'Moth11.png', 'Moth12.png']

# %% [markdown]
# ### Create an html display

# %%
header = """<!DOCTYPE html>
<html>
<head>
<style>
div.gallery {
  border: 1px solid #ccc;
}

div.gallery:hover {
  border: 1px solid #777;
}

div.gallery img {
  width: 100%;
  height: auto;
}

div.desc {
  padding: 15px;
  text-align: center;
}

* {
  box-sizing: border-box;
}

.responsive {
  padding: 0 6px;
  float: left;
  width: 24.99999%;
}

@media only screen and (max-width: 700px) {
  .responsive {
    width: 49.99999%;
    margin: 6px 0;
  }
}

@media only screen and (max-width: 500px) {
  .responsive {
    width: 100%;
  }
}

.clearfix:after {
  content: "";
  display: table;
  clear: both;
}
</style>
</head>
<body>
""" 

bodyContent = f"""<h2>{baseName.title()} Posts Over {image_count} Months </h2>
<h4>Author: Grace Choi</h4>
<h4>Data source: {baseName} GIS 715</h4>"""

mapPics = os.listdir(visDir)

mapPics = [picName for picName in mapPics if picName.endswith('.png') and "legend" not in picName ]

for pic in mapPics:
    dateVal = os.path.splitext(pic)[0]
    dateVal = dateVal.replace(baseName,'')
    dateVal = int(dateVal)

    bodyContent = bodyContent + f"""<div class="responsive"><div class="gallery">
  <a target="_blank" href={pic}>
    <img src={pic} alt="{os.path.splitext(pic)[0]}" width="800" height="600">
  </a>
  <div class="desc">{yearly_count[dateVal]} {baseName.title()} post(s) in {dateVal}</div>
</div></div>"""

# Add legend
legendName = os.path.basename(legendName)
bodyContent = bodyContent + f"""<div class="responsive"><div class="gallery">
  <a target="_blank" href={legendName}>
    <img src={legendName} alt="animation" width="800" height="600">
  </a>
  <div class="desc">{baseName.title()} post count ranges</div>
</div></div>"""

# Add movie
movieName = os.path.basename(movieName)
bodyContent = bodyContent + f"""<div class="responsive"><div class="gallery">
  <a target="_blank" href={movieName}>
    <img src={movieName} alt="animation" width="800" height="600">
  </a>
  <div class="desc">{baseName.title()} posts over time.</div>
</div></div>"""


footer = """</body>
</html>"""

html_file_name = visDir + f'{baseName}.html'

with open( html_file_name,'w') as outFileObject:
  outFileObject.write(header)
  outFileObject.write(bodyContent)
  outFileObject.write(footer)
os.startfile(html_file_name)
